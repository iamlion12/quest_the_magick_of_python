# %% [markdown]
# # Что такое Python и что нам нужно
# ***
#
# Для запуска программы написанной на Python'e необходим интерпретатор.
#
# Интерпретатор - программа, которая служит для выполнения кода.
#
# Интерпретатор пошагово исполняет код исходя из общепринятых правил.
#
# Программа на Python'e - это текст кода, сохраненный в формате ".py".
#
# Чтобы исполнить написанный вами код необходимо вызвать интерпретатор и указать путь к файлу программы.
#
# Пример:
#
# ```sh
# python имя_файла.py
# ```

# %% [markdown]
# # Переменные
# ***
# Название переменной в Python должно начинаться с алфавитного символа или со знака подчеркивания и может содержать алфавитно-цифровые символы и знак подчеркивания. И кроме того, название переменной не должно совпадать с названием ключевых слов языка Python.
#
# ### Присваивание
# Присваивание осуществляется с помощью знака "=", например:
# ```python
# x = 24
# ```
#
#   ***
#
# ### Типы данных
# ![alt text](datatypes.png)

# %%
x = 24 # в переменной x будет храниться число 24

# Не надо объявлять новую переменную, 
# если мы присваем значение с другим типом
# это называется динамическая типизация
x = "Айрат"

# %%
input()
# Out:
# Victor
# 'Victor'

# %% [markdown]
# ### Как узнать тип переменной
# Функция type возращает тип переменной, например:
# ~~~~python
# type(int())
# ~~~~

# %% [markdown]
# # Вывод на экран
# ```python
# print(24)
# ```
# Функция print выводит содержимое на экран, в скобках указывается что нужно распечатать.

# %% [markdown]
# # Ввод
#  ```python
#  input()
#  ```
#  input - ожидает ввода с клавиатуры, ввод оканчивается клавишей Enter.
#  input - всегда возвращает строку.

# %% [markdown]
# # Основные математические операции

# %%
2 + 2 # сложение
2 - 2.24 # вычитание
2 * 2 # умножение
52 / 24.24 # деление, важно результат имеет тип float
2 // 2 # целочисленное деление
2 % 4 # остаток от деления
2 ** 5 # возведение в степень
# Out:
# 32

# %% [markdown]
# # Работа со строками
#  * Конкатенация - сложение строк(оператор +)
#  * Взятие элемента по индексу - обращение к символупо индексу(индекс указывается после строки в квадратных скобках)
#
#         Индексация начинается с нуля

# %% [markdown]
# # Логические операторы
#  ```python
#  1 > 0 # больше
#  1 < 0 # меньше
#  1 >= 0 # больше либо равно
#  1 <= 0 # меньше либо равно
#  1 == 0  # равно
#  2 != 1 # неравно
#  1 and 1 # логическое "И"
#  2 or 2 # логические "или"
# ```

# %% [markdown]
# # Условные операторы и ~~Операторные скобки~~
# Условные конструкции в Python существуют для того,
# чтобы разработчик мог задавать определенное поведение
# программы в зависимости от заданных ей условий.
#
# ### Оператор if
# Оператор if в Python подобен этому оператору в других языках.
# Утверждение с использованием оператора if содержит в себе логическое условие,
# в котором производится сравнение данных и по результату выбирается дальнейшее действие.
# Пример:
# ```python
# if выражение:
#     действие
# ```
# Вслучае если **выражение** окажется истинным,
# интерпретатор выполнит команды из _вложенного блока_.
# &nbsp;
#
# ### Вложенный блок == ~~операторные скобки~~
# Python **не содержит** операторных скобок (begin..end в pascal или {..}в Си),
# вместо этого блоки выделяются отступами: **4 пробелами**,
# а вход в блок из операторов осуществляется двоеточием.

# %%
# например
num = -1
if num > 0:
    print("Если ты это читаешь, значит num > 4")
    print("И эту строчку ты читаешь, потому что передомной тоже есть отступ")
print("На этой строчке отступов нет...")
print("Это значит, что в любом случае, ты это прочтешь.")
# Out:
# На этой строчке отступов нет...
# Это значит, что в любом случае, ты это прочтешь.

# %% [markdown]
# # Оператор else - иначе
# В случае, когда необходимо выполнить действия при ложном
# выражении, описанном после оператора **if**
# можно использовать конструкцию **if .. else**.
# Например:
# ```python
# if выражение:
#     действие_1
# else:
#     действие_2 выполниться если выражение оказалось ложным
# ```
#     **Примечание** Конструкция **else** является необязательной.
# &nbsp;
# &nbsp;
# ## Конструкция if..elif..else:
# Ключевое слово **elif** добавляется в том случае, если необходимо
# проверить _несколько условий не связанных между собой_.
# "Несколько условий" означает, что указывать **elif**
# можно сколько угодно раз.
# ```python
# if выражение:
#     действия, если выражение равно True
# elif выражение2:
#     действия, если выражение2 равно True
# elif выражение3:
#     действия, если выражение3 равно True
# else:
#     действия, в противном случае
# ```

# %%
if 2 > 3 < 4 and 1 or 0:
    print('yes')

# %% [markdown]
# # Задания для самостоятельного выполнения:
# 1. Даны две переменных с некоторыми значениями. Поменять местами значения этих переменных.
# 2. Пользователь вводит НЕЦЕЛОЕ число. Выведите на экран квадрат этого числа и куб этого числа.
# 3. Пользователь вводит три числа - длины сторон треугольника. Сделать проверку на существование треугольника (сумма двух любых сторон должна быть больше 3-й).
# 4. Пользователь вводит своё имя. Если его имя начинается на букву "B"(Виктор, например), то сообщите ему(пользователю), что вам срочно нужно уходить, а если его имя начинается с такой же буквы как и ваше имя, то напишите "Привет!"
